# %%
import pandas as pd
import numpy as np
import tensorflow as tf
tf.random.set_seed(777)
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import load_model

# %%
data=pd.read_csv('okt .csv',encoding = "CP949", engine='python',index_col='Unnamed: 0')
data.head()
# Out:
#                                            제목 통합 분류1  \
# 0          [속보] 한국 축구대표팀 벤투 감독 "감독직 재계약 안 한다"    스포츠
# 1      산란계 농장 질병관리등급제 도입 "방역에 치여 닭 기를 시간도 없다"     지역
# 2  '마약'을 비타민이라 속여 50대女 성폭행한 60대 남성..징역 10년 선고     사회
# 3            경기도청 컬링팀 5G, 스투셀스 브랜트퍼트 닛산클래식 패권    스포츠
# 4              [과학을읽다]합성생물학? '키메라' 아니고 게임체인저!  IT_과학
#
#                                                   본문  \
# 0   아시아경제 서믿음 기자  한국 축구대표팀을 16강에 올린 파울루 벤투 대표팀 감독...
# 1  조류 인플루엔자 AI  방역 정책을 개선하려 지난해 산란계 농장을 대상으로 질병관리...
# 2  기사와 관련 없는 자료 사진  사진 뉴스1   파이낸셜뉴스  지인에게 마약을 비타민...
# 3  6일 캐나다 온토리오 브랜트퍼드에서 열린 2022 스투셀스 브랜트퍼트 닛산 클래식에...
# 4   아시아경제 김봉수 기자  전염병 창궐과 자원 부족 환경 오염에 직면한 21세기  ...
#
#                                           본문정리morphs  \
# 0  ['아시아', '경제', '서', '믿음', '기자', '한국', '축구', '대표...
# 1  ['조류', '인플루엔자', 'AI', '방역', '정책', '을', '개선', '...
# 2  ['기사', '와', '관련', '없다', '자료', '사진', '사진', '뉴스'...
# 3  ['6일', '캐나다', '온', '토리', '오', '브랜트퍼드', '에서', '...
# 4  ['아시아', '경제', '김봉수', '기자', '전염병', '창궐', '과', '...
#
#                                            본문정리nouns  \
# 0  ['아시아', '경제', '믿음', '기자', '한국', '축구', '대표팀', '...
# 1  ['조류', '인플루엔자', '방역', '정책', '개선', '지난해', '산란',...
# 2  ['기사', '관련', '자료', '사진', '사진', '뉴스', '파이낸셜뉴스',...
# 3  ['캐나다', '토리', '오', '브랜트퍼드', '스투셀스', '브랜트', '퍼트...
# 4  ['아시아', '경제', '김봉수', '기자', '전염병', '창궐', '자원', ...
#
#                                              본문정리pos  숫자카테고리
# 0  ['아시아', '경제', '믿음', '기자', '한국', '축구', '대표팀', '...       5
# 1  ['조류', '인플루엔자', '방역', '정책', '개선', '지난해', '산란',...       7
# 2  ['기사', '관련', '없는', '자료', '사진', '사진', '뉴스', '파이...       4
# 3  ['캐나다', '토리', '오', '브랜트퍼드', '스투셀스', '브랜트', '퍼트...       5
# 4  ['아시아', '경제', '김봉수', '기자', '전염병', '창궐', '자원', ...       0

# %%
from sklearn.model_selection import train_test_split


x_train, x_test, y_train, y_test = train_test_split(data['본문정리pos'], data['숫자카테고리'], test_size=0.2, random_state=2021)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=2021)

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(x_train) #빈도수가 높은애로 인덱스 부여
len(tokenizer.word_index)
# Out:
# 30260

# %%
tokenizer.word_index
# Out:
# {"'등'": 1,
#  "'한국'": 2,
#  "'있다'": 3,
#  "'이'": 4,
#  "'기자'": 5,
#  "'것'": 6,
#  "'지난'": 7,
#  "'전'": 8,
#  "'위'": 9,
#  "'사업'": 10,
#  "'지역'": 11,
#  "'명'": 12,
#  "'날'": 13,
#  "'위해'": 14,
#  "'수'": 15,
#  "'를'": 16,
#  "'제'": 17,
#  "'서울'": 18,
#  "'및'": 19,
#  "'이번'": 20,
#  "'있는'": 21,
#  "'대표'": 22,
#  "'월드컵'": 23,
#  "'진행'": 24,
#  "'카타르'": 25,
#  "'개'": 26,
#  "'대한'": 27,
#  "'센터'": 28,
#  "'정부'": 29,
#  "'기업'": 30,
#  "'시간'": 31,
#  "'경제'": 32,
#  "'회'": 33,
#  "'축구'": 34,
#  "'브라질'": 35,
#  "'경기'": 36,
#  "'의'": 37,
#  "'올해'": 38,
#  "'대상'": 39,
#  "'고'": 40,
#  "'내년'": 41,
#  "'위원회'": 42,
#  "'산업'": 43,
#  "'씨'": 44,
#  "'지원'": 45,
#  "'오전'": 46,
#  "'대통령'": 47,
#  "'사진'": 48,
#  "'회장'": 49,
#  "'개최'": 50,
#  "'강'": 51,
#  "'중'": 52,
#  "'통해'": 53,
#  "'최근'": 54,
#  "'화물'": 55,
#  "'국민'": 56,
#  "'미국'": 57,
#  "'의원'": 58,
#  "'문화'": 59,
#  "'은'": 60,
#  "'로'": 61,
#  "'시장'": 62,
#  "'오후'": 63,
#  "'시'": 64,
#  "'관련'": 65,
#  "'행사'": 66,
#  "'가운데'": 67,
#  "'운영'": 68,
#  "'사회'": 69,
#  "'선정'": 70,
#  "'아시아'": 71,
#  "'말'": 72,
#  "'대표팀'": 73,
#  "'전국'": 74,
#  "'국내'": 75,
#  "'추진'": 76,
#  "'교육'": 77,
#  "'지난달'": 78,
#  "'세계'": 79,
#  "'기술'": 80,
#  "'연대'": 81,
#  "'관리'": 82,
#  "'대회'": 83,
#  "'업무'": 84,
#  "'대해'": 85,
#  "'본부'": 86,
#  "'차'": 87,
#  "'정책'": 88,
#  "'강전'": 89,
#  "'개발'": 90,
#  "'시작'": 91,
#  "'투자'": 92,
#  "'제공'": 93,
#  "'현지'": 94,
#  "'평가'": 95,
#  "'달'": 96,
#  "'힘'": 97,
#  "'민주당'": 98,
#  "'내'": 99,
#  "'안전'": 100,
#  "'현장'": 101,
#  "'기관'": 102,
#  "'코로나'": 103,
#  "'서비스'": 104,
#  "'조사'": 105,
#  "'감독'": 106,
#  "'첫'": 107,
#  "'수출'": 108,
#  "'곳'": 109,
#  "'결과'": 110,
#  "'부산'": 111,
#  "'회의'": 112,
#  "'원'": 113,
#  "'이후'": 114,
#  "'국제'": 115,
#  "'국회'": 116,
#  "'그'": 117,
#  "'인천'": 118,
#  "'참석'": 119,
#  "'발표'": 120,
#  "'혐의'": 121,
#  "'시민'": 122,
#  "'입니다'": 123,
#  "'김'": 124,
#  "'협력'": 125,
#  "'주민'": 126,
#  "'그룹'": 127,
#  "'도'": 128,
#  "'윤석열'": 129,
#  "'협회'": 130,
#  "'참여'": 131,
#  "'장관'": 132,
#  "'건설'": 133,
#  "'중국'": 134,
#  "'대한민국'": 135,
#  "'머니투데이'": 136,
#  "'우리'": 137,
#  "'계획'": 138,
#  "'주'": 139,
#  "'협의'": 140,
#  "'대응'": 141,
#  "'선수'": 142,
#  "'기준'": 143,
#  "'공사'": 144,
#  "'국가'": 145,
#  "'법'": 146,
#  "'며'": 147,
#  "'총'": 148,
#  "'세'": 149,
#  "'더'": 150,
#  "'오늘'": 151,
#  "'시설'": 152,
#  "'팀'": 153,
#  "'관'": 154,
#  "'앵커'": 155,
#  "'규모'": 156,
#  "'의회'": 157,
#  "'비'": 158,
#  "'활동'": 159,
#  "'헤럴드경제'": 160,
#  "'마련'": 161,
#  "'후'": 162,
#  "'안'": 163,
#  "'여'": 164,
#  "'울산'": 165,
#  "'과'": 166,
#  "'뒤'": 167,
#  "'파업'": 168,
#  "'발생'": 169,
#  "'광주'": 170,
#  "'때'": 171,
#  "'지난해'": 172,
#  "'인사'": 173,
#  "'일본'": 174,
#  "'분야'": 175,
#  "'일'": 176,
#  "'전자'": 177,
#  "'경찰'": 178,
#  "'주택'": 179,
#  "'도시'": 180,
#  "'예정'": 181,
#  "'환경'": 182,
#  "'대비'": 183,
#  "'전망'": 184,
#  "'보도'": 185,
#  "'우수'": 186,
#  "'진출'": 187,
#  "'공개'": 188,
#  "'대구'": 189,
#  "'글로벌'": 190,
#  "'실시'": 191,
#  "'기념'": 192,
#  "'이상'": 193,
#  "'군'": 194,
#  "'충북'": 195,
#  "'예산'": 196,
#  "'사랑'": 197,
#  "'상황'": 198,
#  "'모두'": 199,
#  "'여성'": 200,
#  "'투'": 201,
#  "'최고'": 202,
#  "'경기도'": 203,
#  "'약'": 204,
#  "'금융'": 205,
#  "'부'": 206,
#  "'발전'": 207,
#  "'나눔'": 208,
#  "'파이낸셜뉴스'": 209,
#  "'위원장'": 210,
#  "'전달'": 211,
#  "'가장'": 212,
#  "'스타디움'": 213,
#  "'사장'": 214,
#  "'방문'": 215,
#  "'단체'": 216,
#  "'건'": 217,
#  "'정보'": 218,
#  "'협약'": 219,
#  "'두'": 220,
#  "'병원'": 221,
#  "'피해'": 222,
#  "'행정'": 223,
#  "'청년'": 224,
#  "'북한'": 225,
#  "'층'": 226,
#  "'같은'": 227,
#  "'눈'": 228,
#  "'활용'": 229,
#  "'앞'": 230,
#  "'대전'": 231,
#  "'주요'": 232,
#  "'도하'": 233,
#  "'이하'": 234,
#  "'최대'": 235,
#  "'기'": 236,
#  "'복지'": 237,
#  "'학교'": 238,
#  "'민주'": 239,
#  "'가격'": 240,
#  "'확대'": 241,
#  "'점'": 242,
#  "'부문'": 243,
#  "'현재'": 244,
#  "'업체'": 245,
#  "'경북'": 246,
#  "'임'": 247,
#  "'특별'": 248,
#  "'거래'": 249,
#  "'베트남'": 250,
#  "'학생'": 251,
#  "'대학'": 252,
#  "'시행'": 253,
#  "'방송'": 254,
#  "'경남'": 255,
#  "'성과'": 256,
#  "'미래'": 257,
#  "'자신'": 258,
#  "'있습니다'": 259,
#  "'조성'": 260,
#  "'전북'": 261,
#  "'공동'": 262,
#  "'무역'": 263,
#  "'직원'": 264,
#  "'프로그램'": 265,
#  "'기록'": 266,
#  "'다양한'": 267,
#  "'사용'": 268,
#  "'처음'": 269,
#  "'또'": 270,
#  "'사람'": 271,
#  "'증가'": 272,
#  "'전략'": 273,
#  "'삼성'": 274,
#  "'노조'": 275,
#  "'공급'": 276,
#  "'윤'": 277,
#  "'일부'": 278,
#  "'사고'": 279,
#  "'단'": 280,
#  "'주관'": 281,
#  "'노총'": 282,
#  "'해당'": 416,
#  "'해외'": 417,
#  "'단지'": 418,
#  "'농협'": 419,
#  "'디지털'": 420,
#  "'의혹'": 421,
#  "'라며'": 422,
#  "'검찰'": 423,
#  "'활성화'": 424,
#  "'승진'": 425,
#  "'연'": 426,
#  "'때문'": 427,
#  "'이태원'": 428,
#  "'카타르월드컵'": 429,
#  "'못'": 430,
#  "'연구원'": 431,
#  "'국'": 432,
#  "'호텔'": 433,
#  "'확보'": 434,
#  "'의무'": 435,
#  "'충남'": 436,
#  "'지속'": 437,
#  "'점검'": 438,
#  "'회사'": 439,
#  "'지정'": 440,
#  "'보고'": 441,
#  "'판사'": 442,
#  "'신청'": 443,
#  "'연합'": 444,
#  "'김장'": 445,
#  "'처리'": 446,
#  "'주년'": 447,
#  "'중앙'": 448,
#  "'공장'": 449,
#  "'포럼'": 450,
#  "'사례'": 451,
#  "'원장'": 452,
#  "'건강'": 453,
#  "'연구'": 454,
#  "'위원'": 455,
#  "'플랫폼'": 456,
#  "'거부'": 457,
#  "'최종'": 458,
#  "'캠페인'": 459,
#  "'논의'": 460,
#  "'중소기업'": 461,
#  "'강화'": 462,
#  "'포'": 463,
#  "'해'": 464,
#  "'관심'": 465,
#  "'구역'": 466,
#  "'교육청'": 467,
#  "'프랑스'": 468,
#  "'차량'": 469,
#  "'소방'": 470,
#  "'불'": 471,
#  "'많은'": 472,
#  "'새벽'": 473,
#  "'명령'": 474,
#  "'목표'": 475,
#  "'노인'": 476,
#  "'소속'": 477,
#  "'없는'": 478,
#  "'기부'": 479,
#  "'미'": 480,
#  "'취임'": 481,
#  "'화재'": 482,
#  "'데이터'": 483,
#  "'노'": 484,
#  "'광장'": 485,
#  "'진'": 486,
#  "'나'": 487,
#  "'자리'": 488,
#  "'하락'": 489,
#  "'제품'": 490,
#  "'모집'": 491,
#  "'물'": 492,
#  "'상품'": 493,
#  "'전문가'": 494,
#  "'수준'": 495,
#  "'공단'": 496,
#  "'어려운'": 497,
#  "'선거'": 498,
#  "'상대로'": 499,
#  "'기존'": 500,
#  "'위반'": 501,
#  "'회원'": 502,
#  "'체육회'": 503,
#  "'용'": 504,
#  "'공연'": 505,
#  "'파울루'": 506,
#  "'장기'": 507,
#  "'자동차'": 508,
#  "'하나'": 509,
#  "'시상식'": 510,
#  "'농업'": 511,
#  "'일자리'": 512,
#  "'작품'": 513,
#  "'유지'": 514,
#  "'높은'": 515,
#  "'도로'": 516,
#  "'롯데'": 517,
#  "'신규'": 518,
#  "'인재'": 519,
#  "'현대'": 520,
#  "'언론'": 521,
#  "'있도록'": 522,
#  "'김치'": 523,
#  "'당국'": 524,
#  "'세종'": 525,
#  "'방역'": 526,
#  "'구축'": 527,
#  "'거리'": 528,
#  "'개인'": 529,
#  "'부동산'": 530,
#  "'개정'": 531,
#  "'관장'": 532,
#  "'통신'": 533,
#  "'출시'": 534,
#  "'공간'": 535,
#  "'완화'": 536,
#  "'있다는'": 537,
#  "'호'": 538,
#  "'매년'": 539,
#  "'구성'": 540,
#  "'새'": 541,
#  "'집'": 542,
#  "'서울시'": 543,
#  "'대표이사'": 544,
#  "'살'": 545,
#  "'확산'": 546,
#  "'체계'": 679,
#  "'촬영'": 680,
#  "'우크라이나'": 681,
#  "'감사'": 682,
#  "'국가주석'": 683,
#  "'중부'": 684,
#  "'구'": 685,
#  "'인근'": 686,
#  "'보유'": 687,
#  "'공모'": 688,
#  "'상'": 689,
#  "'춘천'": 690,
#  "'수도권'": 691,
#  "'전환'": 692,
#  "'작업'": 693,
#  "'발언'": 694,
#  "'감소'": 695,
#  "'작가'": 696,
#  "'검사'": 697,
#  "'군수'": 698,
#  "'기여'": 699,
#  "'지능'": 700,
#  "'치료'": 701,
#  "'인구'": 702,
#  "'전주'": 703,
#  "'사격'": 704,
#  "'설립'": 705,
#  "'하루'": 706,
#  "'수상했다'": 707,
#  "'카카오'": 708,
#  "'문'": 709,
#  "'친환경'": 710,
#  "'사태'": 711,
#  "'소송'": 712,
#  "'파크'": 713,
#  "'촉구'": 714,
#  "'총장'": 715,
#  "'계'": 716,
#  "'버스'": 717,
#  "'선고'": 718,
#  "'건물'": 719,
#  "'임원'": 720,
#  "'각'": 721,
#  "'역량'": 722,
#  "'기온'": 723,
#  "'여야'": 724,
#  "'통합'": 725,
#  "'적용'": 726,
#  "'스포츠'": 727,
#  "'유튜브'": 728,
#  "'형사'": 729,
#  "'팬'": 730,
#  "'이유'": 731,
#  "'체육'": 732,
#  "'계속'": 733,
#  "'드라마'": 734,
#  "'마지막'": 735,
#  "'재정'": 736,
#  "'남성'": 737,
#  "'영하'": 738,
#  "'범죄'": 739,
#  "'시대'": 740,
#  "'처벌'": 741,
#  "'심의'": 742,
#  "'방식'": 743,
#  "'지적'": 744,
#  "'전기차'": 745,
#  "'년'": 746,
#  "'국가대표팀'": 747,
#  "'재산'": 748,
#  "'사상'": 749,
#  "'물가'": 750,
#  "'정비'": 751,
#  "'훈련'": 752,
#  "'통과'": 753,
#  "'대출'": 754,
#  "'주목'": 755,
#  "'자체'": 756,
#  "'강조'": 757,
#  "'회관'": 758,
#  "'뜻'": 759,
#  "'해결'": 760,
#  "'등록'": 761,
#  "'제작'": 762,
#  "'위치'": 763,
#  "'조합원'": 764,
#  "'통상'": 765,
#  "'추위'": 766,
#  "'신고'": 767,
#  "'아트'": 768,
#  "'환자'": 769,
#  "'어린이'": 770,
#  "'유럽'": 771,
#  "'정도'": 772,
#  "'보건'": 773,
#  "'바'": 774,
#  "'운수'": 775,
#  "'상당'": 776,
#  "'해상'": 777,
#  "'가치'": 778,
#  "'지법'": 779,
#  "'현'": 780,
#  "'앱'": 781,
#  "'다른'": 782,
#  "'체험'": 783,
#  "'위험'": 784,
#  "'상생'": 785,
#  "'아니라'": 786,
#  "'북부'": 787,
#  "'겨울철'": 788,
#  "'변화'": 789,
#  "'법원'": 790,
#  "'역사'": 791,
#  "'없다'": 792,
#  "'기능'": 793,
#  "'성금'": 794,
#  "'이혼'": 795,
#  "'참가'": 796,
#  "'유치'": 797,
#  "'이사장'": 798,
#  "'불법'": 799,
#  "'중앙회'": 800,
#  "'보험'": 801,
#  "'상무'": 802,
#  "'창업'": 803,
#  "'접수'": 804,
#  "'소'": 805,
#  "'적'": 806,
#  "'연탄'": 807,
#  "'상담'": 808,
#  "'코리아'": 809,
#  "'수도'": 810,
#  "'크게'": 811,
#  "'종'": 812,
#  "'출범'": 813,
#  "'민선'": 814,
#  "'만큼'": 815,
#  "'커넥트'": 816,
#  "'외국인'": 817,
#  "'각종'": 818,
#  "'봉사'": 819,
#  "'권'": 820,
#  "'소비자'": 821,
#  "'차례'": 822,
#  "'인증'": 823,
#  "'인한'": 824,
#  "'본부장'": 825,
#  "'확정'": 826,
#  "'보이'": 827,
#  "'아침'": 828,
#  "'자'": 829,
#  "'청사'": 830,
#  "'청와대'": 831,
#  "'률'": 832,
#  "'도전'": 833,
#  "'준'": 834,
#  "'가수'": 835,
#  "'여부'": 836,
#  "'네이버'": 837,
#  "'승리'": 838,
#  "'관내'": 839,
#  "'전쟁'": 840,
#  "'성공'": 841,
#  "'무대'": 842,
#  "'남부'": 843,
#  "'공'": 844,
#  "'복합'": 845,
#  "'제출'": 846,
#  "'최강'": 847,
#  "'부회장'": 848,
#  "'양성'": 849,
#  "'대의'": 850,
#  "'전통'": 851,
#  "'면'": 852,
#  "'역대'": 853,
#  "'대규모'": 854,
#  "'게임'": 855,
#  "'재난'": 856,
#  "'창원'": 857,
#  "'노동조합'": 858,
#  "'서해'": 859,
#  "'운동'": 860,
#  "'글'": 861,
#  "'게'": 862,
#  "'왼쪽'": 863,
#  "'주석'": 864,
#  "'스타'": 865,
#  "'밤'": 866,
#  "'자료'": 867,
#  "'지사'": 868,
#  "'선발'": 869,
#  "'사이'": 870,
#  "'확'": 871,
#  "'가정'": 872,
#  "'요청'": 873,
#  "'실천'": 874,
#  "'문재인'": 875,
#  "'중공업'": 876,
#  "'지수'": 877,
#  "'방향'": 878,
#  "'모델'": 879,
#  "'기자간담회'": 880,
#  "'마케팅'": 881,
#  "'급'": 882,
#  "'격려'": 883,
#  "'광화문'": 884,
#  "'돈'": 885,
#  "'행정안전부'": 886,
#  "'시즌'": 887,
#  "'조선'": 888,
#  "'유'": 889,
#  "'홀'": 890,
#  "'가지'": 891,
#  "'로부터'": 892,
#  "'이야기'": 893,
#  "'비상'": 894,
#  "'학년'": 895,
#  "'프로젝트'": 896,
#  "'효과'": 897,
#  "'간담'": 898,
#  "'특'": 899,
#  "'터'": 900,
#  "'역할'": 901,
#  "'식품'": 902,
#  "'노력'": 903,
#  "'디자인'": 904,
#  "'노동자'": 905,
#  "'발견'": 906,
#  "'잉글랜드'": 907,
#  "'경험'": 908,
#  "'어제'": 909,
#  "'표창'": 910,
#  "'탄소'": 911,
#  "'책'": 912,
#  "'청약'": 913,
#  "'부산시'": 914,
#  "'교사'": 915,
#  "'페이'": 916,
#  "'거래소'": 917,
#  "'가능한'": 918,
#  "'법무부'": 919,
#  "'좋은'": 920,
#  "'개정안'": 921,
#  "'율'": 922,
#  "'포인트'": 923,
#  "'내일'": 924,
#  "'창'": 925,
#  "'무'": 926,
#  "'산'": 927,
#  "'분양'": 928,
#  "'택시'": 929,
#  "'변호사'": 930,
#  "'술'": 931,
#  "'도움'": 932,
#  "'협상'": 933,
#  "'폭'": 934,
#  "'목소리'": 935,
#  "'규'": 936,
#  "'투쟁'": 937,
#  "'능력'": 938,
#  "'상임'": 939,
#  "'기회'": 940,
#  "'기본'": 941,
#  "'목적'": 942,
#  "'감'": 943,
#  "'분위기'": 944,
#  "'폭행'": 945,
#  "'한파'": 946,
#  "'소통'": 947,
#  "'전남도'": 948,
#  "'범'": 949,
#  "'차지'": 950,
#  "'결산'": 951,
#  "'다음'": 952,
#  "'제안'": 953,
#  "'네이마르'": 954,
#  "'수원'": 955,
#  "'자율'": 956,
#  "'기대'": 957,
#  "'단계'": 958,
#  "'자유'": 959,
#  "'의미'": 960,
#  "'줄'": 961,
#  "'시멘트'": 962,
#  "'배터리'": 963,
#  "'소개'": 964,
#  "'임금'": 965,
#  "'수상했다고'": 966,
#  "'조정'": 967,
#  "'일원'": 968,
#  "'침체'": 969,
#  "'외'": 970,
#  "'방침'": 971,
#  "'시범'": 972,
#  "'대형'": 973,
#  "'수요'": 974,
#  "'초등학교'": 975,
#  "'상대'": 976,
#  "'채용'": 977,
#  "'오른'": 978,
#  "'달성'": 979,
#  "'판결'": 980,
#  "'후반'": 981,
#  "'통한'": 982,
#  "'방'": 983,
#  "'먼저'": 984,
#  "'원정'": 985,
#  "'공격'": 986,
#  "'해양'": 987,
#  "'시위'": 988,
#  "'인정'": 989,
#  "'심'": 990,
#  "'인해'": 991,
#  "'진자'": 992,
#  "'비용'": 993,
#  "'법정'": 994,
#  "'홍'": 995,
#  "'여의도'": 996,
#  "'어르신'": 997,
#  "'민생'": 998,
#  "'가상'": 999,
#  "'교육부'": 1000,
#  ...}

# %%
threshold=2
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합


# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value
print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 30260
# 등장 빈도가 1번 이하인 희귀 단어의 수: 10188
# 단어 집합에서 희귀 단어의 비율: 33.668208856576335
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 1.6142193265847093

# %%
#빈도가 1회인 단어들은 중요하지않아서 제외
vocab_size = total_cnt - rare_cnt + 2
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 20074

# %%
tokenizer = Tokenizer(vocab_size, oov_token = 'OOV') 
tokenizer.fit_on_texts(x_train) #빈도수가 높은애로 인덱스 부여

# %%
x_train_sequences = tokenizer.texts_to_sequences(x_train)
x_val_sequences = tokenizer.texts_to_sequences(x_val)
x_test_sequences = tokenizer.texts_to_sequences(x_test)

# %%
max_len = max(len(i) for i in x_train_sequences )
print(max_len) #시퀀스 최대길이
# Out:
# 66

# %%
def below_threshold_len(max_len, nested_list):
    count = 0
    for sentence in nested_list:
        if(len(sentence) <= max_len):
            count = count + 1
    print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (count / len(nested_list))*100))
below_threshold_len(max_len, x_train_sequences)
# Out:
# 전체 샘플 중 길이가 66 이하인 샘플의 비율: 100.0

# %%
x_train_pad=pad_sequences(x_train_sequences, maxlen=max_len, truncating='post', padding='post')#패딩
x_val_pad=pad_sequences(x_val_sequences, maxlen=max_len, truncating='post', padding='post')#패딩
x_test_pad=pad_sequences(x_test_sequences, maxlen=max_len, truncating='post', padding='post')#패딩
#truncating='post', padding='post' 앞에꺼는 길이가 안맞을때 뒤에 0으로 채운다는거, 뒤에꺼는 넘어갈때 뒤에 자른다는거

# %%
# y_train=tf.keras.utils.to_categorical(y_train)

# y_val=tf.keras.utils.to_categorical(y_val)

# y_test=tf.keras.utils.to_categorical(y_test)

# %%
import pickle
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
# 장고에서 같은 토크나이저를 사용하기위해 저장

# %%
from xgboost import XGBClassifier

model = XGBClassifier()
model.fit(x_train_pad, y_train)
# Out:
# XGBClassifier(objective='multi:softprob')

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(x_train_pad)
predictions = [round(value) for value in y_pred]
#     evaluate predictions
accuracy = accuracy_score(y_train, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 47.83%

# %%
y_pred = model.predict(x_test_pad)
predictions = [round(value) for value in y_pred]
#     evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Accuracy: 40.78%
